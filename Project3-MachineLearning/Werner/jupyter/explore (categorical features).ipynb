# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Library/Python/2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
train = pd.read_csv('../data/train.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188318 entries, 0 to 188317
# Columns: 132 entries, id to loss
# dtypes: float64(15), int64(1), object(116)
# memory usage: 189.7+ MB

# %%
# train.columns
train[train.dtypes[train.dtypes == 'object'].index]
# Out:
#        cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10  ...   cat107  \
# 0         A    B    A    B    A    A    A    A    B     A  ...        J
# 1         A    B    A    A    A    A    A    A    B     B  ...        K
# 2         A    B    A    A    B    A    A    A    B     B  ...        F
# 3         B    B    A    B    A    A    A    A    B     A  ...        K
# 4         A    B    A    B    A    A    A    A    B     B  ...        G
# 5         A    B    A    A    A    A    A    A    B     A  ...        F
# 6         A    A    A    A    B    A    A    A    A     A  ...        F
# 7         A    B    A    B    A    A    A    A    B     A  ...        I
# 8         A    B    B    B    B    A    A    A    B     B  ...        M
# 9         A    B    A    A    B    B    A    A    B     A  ...        J
# 10        A    B    A    A    A    A    A    A    B     B  ...        F
# 11        A    B    A    A    B    A    A    A    B     B  ...        F
# 12        B    A    A    A    B    A    A    A    A     A  ...        K
# 13        B    A    A    A    B    B    A    A    A     A  ...        G
# 14        A    A    A    A    B    A    A    A    A     A  ...        H
# 15        A    A    A    A    B    B    A    A    A     A  ...        H
# 16        A    B    B    A    A    A    A    A    B     B  ...        F
# 17        A    A    A    A    A    B    A    A    A     A  ...        G
# 18        A    A    B    A    A    B    A    A    A     A  ...        F
# 19        A    A    A    B    A    A    A    A    A     A  ...        K
# 20        B    B    A    B    A    A    A    A    B     A  ...        K
# 21        A    A    A    B    A    B    A    A    A     A  ...        L
# 22        B    A    A    A    B    B    A    A    A     A  ...        K
# 23        B    A    A    B    A    A    A    A    A     A  ...        F
# 24        B    A    A    A    A    A    A    A    A     A  ...        F
# 25        A    A    A    B    A    A    A    A    A     A  ...        F
# 26        A    A    A    A    A    B    A    A    A     A  ...        G
# 27        B    A    A    B    A    A    A    A    A     A  ...        F
# 28        A    B    A    B    A    B    A    A    B     A  ...        I
# 29        A    A    A    A    B    A    A    A    A     A  ...        J
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...      ...
# 188288    A    A    A    B    A    A    A    A    A     A  ...        F
# 188289    A    A    A    A    A    B    A    A    A     A  ...        I
# 188290    A    A    A    B    A    A    A    A    A     A  ...        I
# 188291    B    A    A    A    B    A    A    A    A     A  ...        I
# 188292    B    A    A    A    A    B    A    A    A     A  ...        E
# 188293    A    A    A    B    A    A    A    A    A     A  ...        H
# 188294    A    A    A    B    A    B    A    A    A     A  ...        G
# 188295    A    B    A    A    A    A    A    A    B     A  ...        I
# 188296    A    A    A    A    B    A    B    A    A     A  ...        I
# 188297    A    B    A    A    A    A    A    A    B     A  ...        G
# 188298    A    A    B    A    A    B    A    A    A     A  ...        L
# 188299    A    A    A    A    B    A    A    A    A     A  ...        K
# 188300    A    A    A    B    A    A    A    A    A     A  ...        J
# 188301    A    A    A    A    B    A    A    A    A     A  ...        G
# 188302    A    A    A    B    B    A    A    A    A     A  ...        E
# 188303    A    B    A    B    A    A    A    A    B     B  ...        H
# 188304    A    A    A    A    B    A    A    B    A     A  ...        F
# 188305    A    A    A    A    A    B    A    A    A     A  ...        J
# 188306    A    B    A    A    B    A    A    A    B     A  ...        J
# 188307    B    A    A    A    A    B    A    A    A     A  ...        J
# 188308    A    A    A    A    B    A    A    A    A     A  ...        H
# 188309    A    B    A    B    B    B    A    A    B     A  ...        E
# 188310    A    B    A    A    B    A    A    A    B     A  ...        H
# 188311    A    A    A    A    B    A    A    A    A     A  ...        F
# 188312    A    A    A    A    A    B    A    A    A     A  ...        N
# 188313    A    B    A    A    A    A    A    A    B     A  ...        G
# 188314    A    A    A    A    A    B    A    A    A     A  ...        F
# 188315    A    B    A    A    A    A    A    B    B     A  ...        F
# 188316    A    B    A    A    A    A    A    A    B     B  ...        J
# 188317    B    A    A    B    A    A    A    A    A     A  ...        G
#
#        cat108 cat109 cat110 cat111 cat112 cat113 cat114 cat115 cat116
# 0           G     BU     BC      C     AS      S      A      O     LB
# 1           K     BI     CQ      A     AV     BM      A      O     DP
# 2           A     AB     DK      A      C     AF      A      I     GK
# 3           K     BI     CS      C      N     AE      A      O     DJ
# 4           B      H      C      C      Y     BM      A      K     CK
# 5           B     BI     CS      A     AS     AE      A      K     DJ
# 6           B     BI     DK      A      J     AF      A      K     DJ
# 7           G     BI     EB      G     AH      Y      A      P     LO
# 8           K     BI     BC      C      K     AX      A      Q     IE
# 9           G     BU     DW      A      U      S      J      O     LY
# 10          D     BI     AM      A     AS      H      A      K     GS
# 11          B     BI     AI      A      E     AX      A      K     HK
# 12          K     BI     CS      A      E     AE      A      O     DJ
# 13          A     AB     EG      A     AK      K      E      K     DC
# 14          G     BI     EG      A     AH      L      A      P     MP
# 15          K     BI     CQ      A     AI     BM      C      L     DS
# 16          B     BI     CL      A     AE      A      A      J     DJ
# 17          G     BU     BC      A      A      S      F      O     LE
# 18          D     BI     CS      A     AV      J      F      K     HQ
# 19          K     BI     BS      E      L     BM      A      R     HJ
# 20          K     BI     CS      C      F     AE      A      O     DJ
# 21          K     BI     AI      C     AP      Y      E      P     GC
# 22          I     BI     EB      A     AS     AE      F      N     BY
# 23          B     BI     CS      I     AD     BM      A      K     DP
# 24          A     BI     BT      A     AF     AF      A      I     HX
# 25          B     BI     EB      E     AV     AK      A      K     HL
# 26          D     BI     EG      A     AL      H      E      K     GS
# 27          B     BI     CS      E      E     BM      A      K     DJ
# 28          F     BI     EB      G     AN     AE      C      N     HK
# 29          F     AB     EB      A      U      N      A      M     HG
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...
# 188288      B     BI     EB      E      S      X      A      K     GC
# 188289      F     BI     CO      A      K     AE      F      N     HK
# 188290      F     BI     CO      K      U     AE      A      N     HK
# 188291      K     BI     CL      A     AF     AD      A      N     HQ
# 188292      B     BI     AP      A     AH     AF      E      J     HK
# 188293      G     BU     DW      E     AH      S      A      O     LB
# 188294      B     AR     EL      C      E     AX      J      K     CK
# 188295      F     BI     BT      A      J     AE      A      N     HK
# 188296      K     BI     CL      A     AW     BJ      A      N     HQ
# 188297      D     BI     EG      A      E     AN      A      J     HK
# 188298      K     BI     EL      A     AV     AK      J      O     GK
# 188299      K     BI     BT      A     AH      Y      A      P     GE
# 188300      K     BI     CL      I      E     BN      A      N     HQ
# 188301      D     BI     BT      A     AP     AG      A      L     HK
# 188302      B     AB     EB      C     AV      M      A      J     DJ
# 188303      G     BI     EG      C      B     AD      A      O     LM
# 188304      B     BI     CS      A      U     BM      A      K     HK
# 188305      E     BI     BT      A      J      A      F      N     HK
# 188306      G     BU     DW      A     AS      S      A      O     MD
# 188307      K     BI     CQ      A      K     BM      F      O     IE
# 188308      B     AB     EG      A     AI     BM      A      M     CK
# 188309      A      K     AI      C      J     AW      E      I     DJ
# 188310      B      K     EB      A      J     AE      A      L     CI
# 188311      B     AB     EB      A      J      M      A      J     GK
# 188312      K     BI     EG      A     AS     AE      E      Q     DJ
# 188313      B     BI     EG      A      G     BM      A      L     CK
# 188314      B     BI     BT      A     AV     AU      E      J     DF
# 188315      B     BI     DM      A      W     AF      A      K     DJ
# 188316      K     BI     AI      A     AS     AJ      A      O     MD
# 188317      G     BI     EG      K     AS     AD      A      O     MJ
#
# [188318 rows x 116 columns]

# %%
for col in train[train.dtypes[train.dtypes == 'object'].index]:
    print train[col].value_counts()
# Out:
# A    141550
# B     46768
# Name: cat1, dtype: int64
# A    106721
# B     81597
# Name: cat2, dtype: int64
# A    177993
# B     10325
# Name: cat3, dtype: int64
# A    128395
# B     59923
# Name: cat4, dtype: int64
# A    123737
# B     64581
# Name: cat5, dtype: int64
# A    131693
# B     56625
# Name: cat6, dtype: int64
# A    183744
# B      4574
# Name: cat7, dtype: int64
# A    177274
# B     11044
# Name: cat8, dtype: int64
# A    113122
# B     75196
# Name: cat9, dtype: int64
# A    160213
# B     28105
# Name: cat10, dtype: int64
# A    168186
# B     20132
# Name: cat11, dtype: int64
# A    159825
# B     28493
# Name: cat12, dtype: int64
# A    168851
# B     19467
# Name: cat13, dtype: int64
# A    186041
# B      2277
# Name: cat14, dtype: int64
# A    188284
# B        34
# Name: cat15, dtype: int64
# A    181843
# B      6475
# Name: cat16, dtype: int64
# A    187009
# B      1309
# Name: cat17, dtype: int64
# A    187331
# B       987
# Name: cat18, dtype: int64
# A    186510
# B      1808
# Name: cat19, dtype: int64
# A    188114
# B       204
# Name: cat20, dtype: int64
# A    187905
# B       413
# Name: cat21, dtype: int64
# A    188275
# B        43
# Name: cat22, dtype: int64
# A    157445
# B     30873
# Name: cat23, dtype: int64
# A    181977
# B      6341
# Name: cat24, dtype: int64
# A    169969
# B     18349
# Name: cat25, dtype: int64
# A    177119
# B     11199
# Name: cat26, dtype: int64
# A    168250
# B     20068
# Name: cat27, dtype: int64
# A    180938
# B      7380
# Name: cat28, dtype: int64
# A    184593
# B      3725
# Name: cat29, dtype: int64
# A    184760
# B      3558
# Name: cat30, dtype: int64
# A    182980
# B      5338
# Name: cat31, dtype: int64
# A    187107
# B      1211
# Name: cat32, dtype: int64
# A    187361
# B       957
# Name: cat33, dtype: int64
# A    187734
# B       584
# Name: cat34, dtype: int64
# A    188105
# B       213
# Name: cat35, dtype: int64
# A    156313
# B     32005
# Name: cat36, dtype: int64
# A    165729
# B     22589
# Name: cat37, dtype: int64
# A    169323
# B     18995
# Name: cat38, dtype: int64
# A    183393
# B      4925
# Name: cat39, dtype: int64
# A    180119
# B      8199
# Name: cat40, dtype: int64
# A    181177
# B      7141
# Name: cat41, dtype: int64
# A    186623
# B      1695
# Name: cat42, dtype: int64
# A    184110
# B      4208
# Name: cat43, dtype: int64
# A    172716
# B     15602
# Name: cat44, dtype: int64
# A    183991
# B      4327
# Name: cat45, dtype: int64
# A    187436
# B       882
# Name: cat46, dtype: int64
# A    187617
# B       701
# Name: cat47, dtype: int64
# A    188049
# B       269
# Name: cat48, dtype: int64
# A    179127
# B      9191
# Name: cat49, dtype: int64
# A    137611
# B     50707
# Name: cat50, dtype: int64
# A    187071
# B      1247
# Name: cat51, dtype: int64
# A    179505
# B      8813
# Name: cat52, dtype: int64
# A    172949
# B     15369
# Name: cat53, dtype: int64
# A    183762
# B      4556
# Name: cat54, dtype: int64
# A    188173
# B       145
# Name: cat55, dtype: int64
# A    188136
# B       182
# Name: cat56, dtype: int64
# A    185296
# B      3022
# Name: cat57, dtype: int64
# A    188079
# B       239
# Name: cat58, dtype: int64
# A    188018
# B       300
# Name: cat59, dtype: int64
# A    187872
# B       446
# Name: cat60, dtype: int64
# A    187596
# B       722
# Name: cat61, dtype: int64
# A    188273
# B        45
# Name: cat62, dtype: int64
# A    188239
# B        79
# Name: cat63, dtype: int64
# A    188271
# B        47
# Name: cat64, dtype: int64
# A    186056
# B      2262
# Name: cat65, dtype: int64
# A    179982
# B      8336
# Name: cat66, dtype: int64
# A    187626
# B       692
# Name: cat67, dtype: int64
# A    188176
# B       142
# Name: cat68, dtype: int64
# A    188011
# B       307
# Name: cat69, dtype: int64
# A    188295
# B        23
# Name: cat70, dtype: int64
# A    178646
# B      9672
# Name: cat71, dtype: int64
# A    118322
# B     69996
# Name: cat72, dtype: int64
# A    154275
# B     34017
# C        26
# Name: cat73, dtype: int64
# A    184731
# B      3561
# C        26
# Name: cat74, dtype: int64
# A    154307
# B     34010
# C         1
# Name: cat75, dtype: int64
# A    181347
# B      6183
# C       788
# Name: cat76, dtype: int64
# D    187503
# C       408
# B       358
# A        49
# Name: cat77, dtype: int64
# B    186526
# A       788
# C       645
# D       359
# Name: cat78, dtype: int64
# B    152929
# D     26657
# A      7064
# C      1668
# Name: cat79, dtype: int64
# D    137505
# B     46538
# C      3492
# A       783
# Name: cat80, dtype: int64
# D    154385
# B     24132
# C      9013
# A       788
# Name: cat81, dtype: int64
# B    147536
# A     19322
# D     18805
# C      2655
# Name: cat82, dtype: int64
# B    141534
# A     26038
# D     15788
# C      4958
# Name: cat83, dtype: int64
# C    154939
# A     29450
# D      3498
# B       431
# Name: cat84, dtype: int64
# B    186005
# C      1011
# A       788
# D       514
# Name: cat85, dtype: int64
# B    103852
# D     72587
# C     10290
# A      1589
# Name: cat86, dtype: int64
# B    166992
# D     11719
# C      8819
# A       788
# Name: cat87, dtype: int64
# A    168926
# D     19302
# E        83
# B         7
# Name: cat88, dtype: int64
# A    183744
# B      4312
# C       220
# D        33
# E         5
# I         2
# H         1
# G         1
# Name: cat89, dtype: int64
# A    177993
# B      9515
# C       728
# D        70
# E         6
# F         4
# G         2
# Name: cat90, dtype: int64
# A    111028
# B     42630
# G     26734
# C      6400
# D      1149
# E       254
# F        97
# H        26
# Name: cat91, dtype: int64
# A    124689
# H     62901
# B       628
# C        62
# I        26
# D        11
# F         1
# Name: cat92, dtype: int64
# D    150237
# C     35788
# B      1133
# E       728
# A       432
# Name: cat93, dtype: int64
# D    121642
# B     51710
# C     13623
# A       738
# F       494
# E        91
# G        20
# Name: cat94, dtype: int64
# C    87531
# D    79525
# E    17417
# A     3736
# B      109
# Name: cat95, dtype: int64
# E    174360
# D      7922
# B      2957
# G      2665
# F       343
# A        35
# C        24
# I        12
# Name: cat96, dtype: int64
# C    78127
# E    47450
# A    41970
# G    16745
# D     3779
# F      213
# B       34
# Name: cat97, dtype: int64
# A    105492
# D     50557
# C     21485
# E     10242
# B       542
# Name: cat98, dtype: int64
# P    79455
# T    72591
# R    10290
# D     8844
# S     7045
# N     2894
# K     2703
# F     2702
# E     1034
# C      310
# J      245
# H       93
# M       52
# I       38
# G       19
# O        3
# Name: cat99, dtype: int64
# F    42970
# I    39933
# L    19961
# K    13817
# G    12935
# J    12027
# H    10776
# A     9402
# N     7592
# B     6608
# O     5697
# M     5185
# C      836
# D      553
# E       26
# Name: cat100, dtype: int64
# A    106721
# D     17171
# C     16971
# G     10944
# F     10139
# J      7259
# I      6690
# M      3669
# L      3173
# Q      2762
# O      2493
# S       173
# R       138
# E         7
# B         3
# K         2
# H         1
# U         1
# N         1
# Name: cat101, dtype: int64
# A    177274
# B      5155
# C      4929
# E       482
# D       449
# G        15
# F        12
# H         1
# J         1
# Name: cat102, dtype: int64
# A    123737
# B     33342
# C     16508
# D      7806
# E      4473
# F      1528
# G       550
# H       190
# I       109
# J        45
# L        17
# K        11
# N         2
# Name: cat103, dtype: int64
# E    42925
# G    40660
# D    27611
# F    19228
# H    17187
# K    14297
# I    10919
# C     6949
# L     3486
# J     3138
# M     1156
# O      409
# N      153
# P       86
# A       68
# B       43
# Q        3
# Name: cat104, dtype: int64
# E    76493
# F    62892
# G    20613
# D    12172
# H    11258
# I     2941
# J      694
# K      486
# C      275
# M      171
# L      145
# A       77
# N       64
# P       15
# O        9
# B        5
# Q        4
# R        2
# S        1
# T        1
# Name: cat105, dtype: int64
# G    47165
# H    37713
# F    36143
# I    21433
# J    18281
# E    13000
# K     7958
# L     2971
# D     1934
# M     1176
# N      231
# C      129
# A       75
# O       66
# R       32
# B        9
# P        2
# Name: cat106, dtype: int64
# F    47310
# G    28560
# H    23461
# J    22405
# K    20236
# I    20066
# E    12521
# L     6976
# D     3225
# M     2067
# N      797
# C      213
# Q      140
# O      125
# P      100
# A       75
# U       32
# R        5
# B        2
# S        2
# Name: cat107, dtype: int64
# B    65512
# K    42435
# G    21421
# D    19160
# F    10242
# A     9299
# E     7968
# I     7243
# H     4305
# C      520
# J      213
# Name: cat108, dtype: int64
# BI    152918
# AB     21933
# BU      3142
# K       2999
# G       1353
# BQ      1067
# N        461
# M        446
# BO       329
# BH       257
# D        214
# AR       208
# AT       200
# CL       178
# AS       159
# AL       151
# R        149
# CD       143
# F        124
# BL       122
# CI       109
# I         94
# L         89
# U         78
# AW        74
# H         73
# Q         66
# CA        66
# BX        61
# T         59
#        ...
# BC        14
# CK        13
# CF        12
# V         11
# BS         9
# AY         9
# CE         8
# AF         8
# CG         8
# P          8
# CJ         8
# AP         7
# CH         6
# AV         6
# BE         5
# BY         3
# BG         3
# BM         2
# AO         2
# BT         2
# BV         2
# BN         2
# J          1
# CB         1
# BF         1
# B          1
# AG         1
# AK         1
# ZZ         1
# BP         1
# Name: cat109, dtype: int64
# CL    25305
# EG    24654
# CS    24592
# EB    21396
# CO    17495
# BT    16365
# EL     9236
# BC     4131
# DW     3640
# CQ     3271
# DX     3096
# AI     2965
# BP     2867
# W      2703
# C      2681
# AC     2611
# CM     1925
# BS     1920
# DK     1745
# V      1692
# A      1296
# EE     1185
# EF     1159
# CI     1066
# DM      796
# CR      767
# AM      643
# AD      626
# AP      576
# T       529
#       ...
# BY        8
# CW        8
# H         8
# AG        7
# CX        6
# BB        6
# DB        4
# EK        4
# BU        4
# AH        4
# DD        3
# Q         3
# DT        3
# AN        3
# AF        3
# EI        2
# DN        2
# CU        2
# EJ        2
# BN        2
# BV        2
# BK        1
# EH        1
# AS        1
# CB        1
# BD        1
# BM        1
# DV        1
# BI        1
# S         1
# Name: cat110, dtype: int64
# A    128395
# C     32401
# E     14682
# G      7039
# I      3578
# K      1353
# M       473
# O       221
# Q        91
# S        38
# W        16
# U        16
# B         7
# D         3
# F         3
# Y         2
# Name: cat111, dtype: int64
# E     25148
# AH    18639
# AS    17669
# J     16222
# AF     9368
# AN     9138
# N      8453
# U      8356
# AV     7122
# AK     6726
# K      6059
# AI     4749
# S      4201
# AP     4000
# G      3168
# F      3149
# AW     3145
# A      2411
# AR     2365
# C      2257
# O      2183
# D      1645
# AD     1531
# AY     1414
# Y      1351
# AG     1331
# AT     1272
# AA     1241
# AM     1170
# AL     1130
# R      1123
# AX     1074
# I       940
# X       925
# AE      834
# Q       793
# V       693
# H       548
# AO      534
# T       521
# L       493
# W       461
# AC      454
# M       439
# AU      434
# B       423
# P       406
# AB      246
# BA      190
# AJ      144
# AQ       30
# Name: cat112, dtype: int64
# BM    26191
# AE    22030
# L     13058
# AX    12661
# Y     11374
# K      7738
# S      7033
# X      7016
# AF     6079
# AN     5214
# H      5094
# AT     4664
# AJ     4425
# AD     4419
# AS     3901
# AK     3520
# BN     3486
# I      3279
# A      3269
# J      3105
# N      2839
# BC     2793
# Q      2784
# BJ     2605
# M      2485
# AG     2415
# AW     1825
# BG     1804
# AU     1630
# AO     1628
#       ...
# BO     1413
# BH     1221
# BK      693
# AV      528
# AY      466
# AM      450
# AI      440
# BF      347
# BD      337
# AH      209
# C       143
# BB       53
# BA       42
# BI       32
# G        18
# AB       18
# AQ       17
# V        15
# U        11
# O        10
# E         7
# AP        6
# BL        3
# BE        3
# AL        3
# T         2
# B         1
# AC        1
# P         1
# AR        1
# Name: cat113, dtype: int64
# A    131693
# C     16793
# E     16475
# J      8199
# F      7905
# N      2455
# I      2432
# R       912
# L       870
# U       250
# O       240
# Q        43
# V        33
# B         6
# D         5
# S         4
# G         1
# W         1
# X         1
# Name: cat114, dtype: int64
# K    43866
# O    26813
# J    23895
# N    22438
# P    21538
# L    16125
# M    12444
# Q     8258
# I     7090
# H     2793
# R     2038
# G      315
# F      269
# S      250
# A       75
# T       56
# U       26
# E       11
# W        6
# X        5
# D        4
# B        2
# C        1
# Name: cat115, dtype: int64
# HK    21061
# DJ    20244
# CK    10162
# DP     9202
# GS     8736
# CR     6862
# HX     5629
# DC     4557
# HG     4414
# IE     4225
# HQ     4044
# HV     3853
# GC     3803
# LM     3277
# LB     3194
# LN     3127
# KW     3085
# HJ     2741
# GK     2632
# DF     2519
# IG     2269
# LO     2082
# HB     2007
# MD     1960
# CB     1909
# LF     1873
# GI     1835
# BY     1620
# KC     1513
# GE     1399
#       ...
# FS        1
# C         1
# IX        1
# MF        1
# JD        1
# J         1
# HU        1
# AE        1
# AD        1
# HO        1
# AH        1
# AM        1
# DY        1
# MS        1
# JO        1
# AN        1
# AP        1
# AS        1
# MT        1
# AR        1
# DQ        1
# MH        1
# JI        1
# AT        1
# G         1
# FO        1
# FN        1
# MB        1
# JK        1
# IB        1
# Name: cat116, dtype: int64

# %%
# Count of each label in each category

#names of all the columns
cols = train.columns

#Plot count plot for all attributes in a 29x4 grid
n_cols = 4
n_rows = 29
for i in range(n_rows):
    fg, ax = plt.subplots(nrows=1, ncols=n_cols, sharey=True, figsize=(16, 10))
    for j in range(n_cols):
        sns.countplot(x=cols[i*n_cols+j], data=train, ax=ax[j])

#cat1 to cat72 have only two labels A and B. In most of the cases, B has very few entries
#cat73 to cat 108 have more than two labels
#cat109 to cat116 have many labels
